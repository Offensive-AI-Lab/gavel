# %%
import os
import json

# === Config ===
target_dir = "negative_tax_scam"
os.makedirs(target_dir, exist_ok=True)  # ensure parent exists

# === Create 1..100 JSON files ===
for i in range(23, 101):  # includes 100
    path = os.path.join(target_dir, f"{i}.json")
    # put whatever skeleton you want inside each file
    with open(path, "w", encoding="utf-8") as f:
        json.dump({}, f, ensure_ascii=False, indent=2)

print(f"Created 100 JSON files in '{target_dir}'.")
# Out:
# Created 100 JSON files in 'negative_tax_scam'.
